# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from pathlib import Path

# %%
data_dir = os.path.join(Path.cwd().parent, "data")

# %%
df = pd.read_csv(data_dir + "\\train_csv.csv", index_col=0)
df.head()
# Out:
#                                                image  label
# 0  c:\Users\Jashan Shah\GitHub\FruitVegetableClas...  apple
# 1  c:\Users\Jashan Shah\GitHub\FruitVegetableClas...  apple
# 2  c:\Users\Jashan Shah\GitHub\FruitVegetableClas...  apple
# 3  c:\Users\Jashan Shah\GitHub\FruitVegetableClas...  apple
# 4  c:\Users\Jashan Shah\GitHub\FruitVegetableClas...  apple

# %%
image = plt.imread(df["image"][200])
image = image.copy()
print(image.shape)

image.resize((2240, 2000, ))
plt.imshow(image)
print(image.shape)
# Out:
# (2240, 2000, 3)
# (2240, 2000)
